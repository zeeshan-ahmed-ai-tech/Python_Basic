# %% [markdown]
# <a href="https://colab.research.google.com/github/zeeshan-ahmed-ai-tech/Python_Basic/blob/main/conditional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter Number: "))

if num>0:
  print("Positive")
elif num<0:
  print("negative")
else:
  print("zero")
# Out:
# Enter Number: 0
# zero
